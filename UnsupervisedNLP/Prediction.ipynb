# %% [markdown]
# # Unsupervisded Sentiment Analysis by word2vec + K-means clustering (3)

# %% [markdown]
# #### By Joyce Jiang | Code by Joyce

# %% [markdown]
# ### There are three steps of this unsupervised NPL analysis:
# (1) word2vec model training
#
# (2) K-means clustering to group words into positive and negative clusters
#
# (3) Perform unsupervised NLP and predict sentiments of data sample

# %% [markdown]
# ### Citation & Source of my code
# Declare: Though I have prior knowledge of conducting text categorization through word2vec and K-means, my script (from 1 to 3) is almost fully adapted from rafaljanwojciki's tutorial on GitHub, under his repo Unsupervised-Sentiment-Analysis, you can check it out at https://github.com/rafaljanwojcik/Unsupervised-Sentiment-Analysis.
#
# Thanks rafaljanwojciki for explaining in a digestible way for me to understand fully how to use word2vec and k-means for a supervised NLP. This script is published for study and research exploration purpose only, and it would not be used for any commercial purpose.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
from IPython.display import display

# %%
final_file = pd.read_csv('test_dataset.csv')
final_file.rename(columns = {'SENTIMENT':'Sentiment','Tweet':'old_Tweet','old_Tweet':'Tweet'}, inplace = True) 
final_file
# Out:
#                                               old_Tweet  \
# 0     ['his', 'excellency', 'president', 'uganda', '...
# 1     ['katabasasa', 'nbstv', 'nbsfrontline', 'nbsup...
# 2     ['mr', 'erias', 'lukwago', 'should', 'know', '...
# 3     ['energy', 'minister', 'drkitutu', 'hands', 'o...
# 4     ['15', 'new', 'covid', '19', 'cases', 'have', ...
# ...                                                 ...
# 5027  ['oworisylvia', 'we', 'have', 'been', 'engagin...
# 5028  ['major', 'rubalamira', 'owc', 'ug', 'has', 'b...
# 5029  ['it', 'is', 'going', 'to', 'be', 'very', 'dif...
# 5030  ['for', 'making', 'the', 'covid19ug', 'lockdow...
# 5031  ['janetmuseveni', 'on', 'learning', '!', 'news...
#
#                                                   Tweet  Sentiment
# 0     his excellency president uganda kagutamuseveni...        1.0
# 1     katabasasa nbstv nbsfrontline nbsupdates alrig...        NaN
# 2     mr erias lukwago should know that sops are ins...        NaN
# 3     energy minister drkitutu hands over the ugx 20...        NaN
# 4     15 new covid 19 cases have been confirmed by t...        NaN
# ...                                                 ...        ...
# 5027  oworisylvia we have been engaging directly the...        NaN
# 5028  major rubalamira owc ug has been supplied by t...        NaN
# 5029  it is going to be very difficult for governmen...        NaN
# 5030  for making the covid19ug lockdown bearable tha...        NaN
# 5031  janetmuseveni on learning ! news thankyouugand...        NaN
#
# [5032 rows x 3 columns]

# %% [markdown]
# #### Unzip words from sentiment dictionary

# %%
sentiment_map = pd.read_csv('sentiment_dictionary.csv')
sentiment_dict = dict(zip(sentiment_map.words.values, sentiment_map.sentiment_coeff.values))

# %%
file_weighting = final_file.copy()

# %% [markdown]
# ##### Apply TF-IDF function to words in each tweet

# %% [markdown]
# #### *TF-IDF: a model to measure the importance of each word in a document
#
# William Scott gives a clear explanation of what TF-IDF is. In his blog on Medium, he explains how the model calculate the importance of a word based on its frequency and document length by using a log computation. Check it out at https://towardsdatascience.com/tf-idf-for-document-ranking-from-scratch-in-python-on-real-world-dataset-796d339a4089

# %%
tfidf = TfidfVectorizer(tokenizer=lambda y: y.split(), norm=None)
tfidf.fit(file_weighting.Tweet)
features = pd.Series(tfidf.get_feature_names())
transformed = tfidf.transform(file_weighting.Tweet)
# Out:
# C:\Users\Joyce\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:507: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"

# %%
def create_tfidf_dictionary(x, transformed_file, features):
    '''
    create dictionary for each input sentence x, where each word has assigned its tfidf score
    
    inspired  by function from this wonderful article: 
    https://medium.com/analytics-vidhya/automated-keyword-extraction-from-articles-using-nlp-bfd864f41b34
    
    x - row of dataframe, containing sentences, and their indexes,
    transformed_file - all sentences transformed with TfidfVectorizer
    features - names of all words in corpus used in TfidfVectorizer

    '''
    vector_coo = transformed_file[x.name].tocoo()
    vector_coo.col = features.iloc[vector_coo.col].values
    dict_from_coo = dict(zip(vector_coo.col, vector_coo.data))
    return dict_from_coo

def replace_tfidf_words(x, transformed_file, features):
    '''
    replacing each word with it's calculated tfidf dictionary with scores of each word
    x - row of dataframe, containing sentences, and their indexes,
    transformed_file - all sentences transformed with TfidfVectorizer
    features - names of all words in corpus used in TfidfVectorizer
    '''
    dictionary = create_tfidf_dictionary(x, transformed_file, features)   
    return list(map(lambda y:dictionary[f'{y}'], x.Tweet.split()))

# %%
# %%time
replaced_tfidf_scores = file_weighting.apply(lambda x: replace_tfidf_words(x, transformed, features), axis=1)#this step takes around 3-4 minutes minutes to calculate
# Out:
# Wall time: 1.41 s

# %%
def replace_sentiment_words(word, sentiment_dict):
    '''
    replacing each word with its associated sentiment score from sentiment dict
    '''
    try:
        out = sentiment_dict[word]
    except KeyError:
        out = 0
    return out

# %% [markdown]
# #### Map sentiment scores from sentiment dictionary

# %%
replaced_closeness_scores = file_weighting.Tweet.apply(lambda x: list(map(lambda y: replace_sentiment_words(y, sentiment_dict), x.split())))

# %%
file_weighting.Sentiment.value_counts()
# Out:
#  1.0    36
# -1.0    35
# Name: Sentiment, dtype: int64

# %% [markdown]
# #### Use dot product in vector to calculate sentiment_rate of each tweet

# %%
replacement_df = pd.DataFrame(data=[replaced_closeness_scores, replaced_tfidf_scores, file_weighting.Tweet, file_weighting.Sentiment]).T
replacement_df.columns = ['sentiment_coeff', 'tfidf_scores', 'sentence', 'Label_sentiment']
replacement_df['sentiment_rate'] = replacement_df.apply(lambda x: np.array(x.loc['sentiment_coeff']) @ np.array(x.loc['tfidf_scores']), axis=1)
replacement_df
# Out:
#                                         sentiment_coeff  \
# 0     [-1.541800827499423, -2.3033457333645297, -1.6...
# 1     [0, -1.5565653208367431, -3.2015054954053355, ...
# 2     [-1.2957153680580322, -3.188078768336516, -1.7...
# 3     [-3.0098813755615854, -1.7890353035388755, 0, ...
# 4     [-1.1767939877229152, -1.3548661756600078, -1....
# ...                                                 ...
# 5027  [-2.835482437494105, -1.7283063267743914, -1.7...
# 5028  [-1.1904924649395259, 0, -3.8522682417561738, ...
# 5029  [-1.6771065597055412, -1.6522155987037777, -1....
# 5030  [-1.9038026048395025, -2.2224452127640792, -1....
# 5031  [-2.3056413928982598, -1.4600265383343334, -2....
#
#                                            tfidf_scores  \
# 0     [4.744648013664831, 8.42515921810825, 3.680227...
# 1     [8.830624326216416, 4.618496728337931, 6.34571...
# 2     [6.227934640772031, 8.137477145656469, 7.73201...
# 3     [7.91433359434226, 5.069424210522852, 8.830624...
# 4     [6.089784302291213, 7.918502198907333, 6.69165...
# ...                                                 ...
# 5027  [7.577861357721047, 5.326215670656147, 2.83044...
# 5028  [7.444329965096524, 8.830624326216416, 7.22118...
# 5029  [3.2120366976234456, 2.4155273670448194, 4.744...
# 5030  [2.4788663896469894, 6.02726394530988, 1.49531...
# 5031  [7.03886485698836, 2.6610135937249586, 6.63339...
#
#                                                sentence Label_sentiment  \
# 0     his excellency president uganda kagutamuseveni...               1
# 1     katabasasa nbstv nbsfrontline nbsupdates alrig...             NaN
# 2     mr erias lukwago should know that sops are ins...             NaN
# 3     energy minister drkitutu hands over the ugx 20...             NaN
# 4     15 new covid 19 cases have been confirmed by t...             NaN
# ...                                                 ...             ...
# 5027  oworisylvia we have been engaging directly the...             NaN
# 5028  major rubalamira owc ug has been supplied by t...             NaN
# 5029  it is going to be very difficult for governmen...             NaN
# 5030  for making the covid19ug lockdown bearable tha...             NaN
# 5031  janetmuseveni on learning ! news thankyouugand...             NaN
#
#       sentiment_rate
# 0        -356.488838
# 1        -522.359925
# 2        -369.949592
# 3        -714.016576
# 4        -343.314726
# ...              ...
# 5027     -519.271275
# 5028     -504.140840
# 5029     -425.720320
# 5030      -47.974229
# 5031      -75.703055
#
# [5032 rows x 5 columns]

# %% [markdown]
# #### *Checking average score of all sentiment, we can see that the avg score is -248, which means my model is highly twisted

# %%
replacement_df.mean()
# Out:
# Label_sentiment      0.014085
# sentiment_rate    -248.239124
# dtype: float64

# %%
#Convert [Polarity] to positive (1), negative (-1), and neutral (0) for comparison

prediction = [-1 if v < -100 else 1 for v in replacement_df['sentiment_rate']]
replacement_df['prediction'] = prediction

# %%
replacement_df=replacement_df.drop_duplicates(subset ="sentence").reset_index(drop=True)
replacement_df.prediction.value_counts()
# Out:
# -1    4106
#  1     850
# Name: prediction, dtype: int64

# %%
df_drop=replacement_df.dropna()
filter_df=df_drop[df_drop['Label_sentiment']!=0]
filter_df=filter_df.reset_index(drop=True)

# %% [markdown]
# ####  The following section is for performing confusion matrix. Since I didn't label [Sentiment] in Boolean (0/1), I was not able to perform a confusion matrix.

# %%
'''predicted_classes = df_drop.prediction
y_test = df_drop.Label_sentiment

conf_matrix = pd.DataFrame(confusion_matrix(df_drop.Label_sentiment, df_drop.prediction))
print('Confusion Matrix')
display(conf_matrix)

test_scores = accuracy_score(y_test,predicted_classes), precision_score(y_test, predicted_classes), recall_score(y_test, predicted_classes), f1_score(y_test, predicted_classes)

print('\n \n Scores')
scores = pd.DataFrame(data=[test_scores])
scores.columns = ['accuracy', 'precision', 'recall', 'f1']
scores = scores.T
scores.columns = ['scores']
display(scores)'''
# Out:
# "predicted_classes = df_drop.prediction\ny_test = df_drop.Label_sentiment\n\nconf_matrix = pd.DataFrame(confusion_matrix(df_drop.Label_sentiment, df_drop.prediction))\nprint('Confusion Matrix')\ndisplay(conf_matrix)\n\ntest_scores = accuracy_score(y_test,predicted_classes), precision_score(y_test, predicted_classes), recall_score(y_test, predicted_classes), f1_score(y_test, predicted_classes)\n\nprint('\n \n Scores')\nscores = pd.DataFrame(data=[test_scores])\nscores.columns = ['accuracy', 'precision', 'recall', 'f1']\nscores = scores.T\nscores.columns = ['scores']\ndisplay(scores)"

# %% [markdown]
# ### Test Accuracy
# Notice: The accuracy test is not valid for my sentiment analysis because I wasn't able to label positive and negative words.
#
# Interestingly, I was able to label my words in English and non-English words. The tweet received prediction of positive means it's dominated by non-English content, vice versa. That's also why we get way more negative labels than positive ones.

# %%
n=0

for i in range(len(filter_df['prediction'])):
    if filter_df['prediction'][i]==filter_df['Label_sentiment'][i]:
        n+=1
OverallAccuracy = n/len(filter_df['prediction'])*100

# %%
positive = filter_df[filter_df['Label_sentiment']==1]
negative = filter_df[filter_df['Label_sentiment']==-1]

positive=positive.reset_index(drop=True)
negative=negative.reset_index(drop=True)

ng=0

for i in range(len(negative['Label_sentiment'])):
    if negative['Label_sentiment'][i]==negative['prediction'][i]:
        ng+=1
NegativeAccuracy = ng/len(negative['Label_sentiment'])*100

p=0

for i in range(len(positive['Label_sentiment'])):
    if positive['Label_sentiment'][i]==positive['prediction'][i]:
        p+=1
PositiveAccuracy = p/len(positive['Label_sentiment'])*100

# %%
print("Overall Accuracy: "+ str(OverallAccuracy))
print("Negative Accuracy: "+ str(NegativeAccuracy))
print("Positive Accuracy: "+ str(PositiveAccuracy))
# Out:
# Overall Accuracy: 47.88732394366197
# Negative Accuracy: 88.57142857142857
# Positive Accuracy: 8.333333333333332

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)

filter_df[['sentence','Label_sentiment','sentiment_rate','prediction']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                       sentence Label_sentiment  sentiment_rate  prediction
# 0                                                                                                                                                                                                     his excellency president uganda kagutamuseveni recognising efforts of ahmadiyya muslim community towards covid19ug so grateful to our partners humanityfirstuk ughumanityfirst hfi1995 4 support accorded to the ppl of uganda ntvuganda eidmubarak eidulfitr nbsupdates               1     -356.488838          -1
# 1                                                                                                                                                                                                          yes he is one of the most celebrated journalists of our time yes he is the reigning bbc komla dumor award winner but he is still humble enough to carry video equipment with the rest of us to the frontlines of the covid19 field the lesson is humility covid19ug               1     -591.000997          -1
# 2                                                                                                                                                                                                aajtak social distancing is a myth anybody can see this now a days on road in streets at local market and at shops it s very dangerous at this time social distancing covid19ug aamaadmiparty delhicm ndtv indiatv hindustantimmes timesofindia bbcnews zeenews dainikbhasker              -1     -321.754354          -1
# 3                                                                                                                                                                                                                                                                                                                                                                              covid19ug cases have been smalolized from 264 to 145 where is the luwero hajji we celebrate ? !               1      -79.117716           1
# 4                                                                                                                                                                                                                                                                                                                            football256 update prolinefc are uncontended though they accept to the fact that they ve been relegated due to the coronavirus pandemic covid19ug              -1     -196.798208          -1
# 5                                                                                                                                                                                                                                                                                                                                                                                                                     covid19ug messed me up i would be here talking to my dog              -1      -99.618699           1
# 6                                                                                                                                                                                                                                                                                                                         i don t think that covid19ug should stop elections i don t think that the millions who vote attend political rallies katikkiroonthespot ntvonthespot              -1     -362.548436          -1
# 7                                                                                                                                                                                              nbsfrontline should change the opposition frontliners none of them is discussing substance all of them think president m7 has failed to manage covid19ug are blaming his tea taking skills if indeed he has failed why do we have the least cases in the region amp no deaths ?              -1     -536.405473          -1
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                  for accurate info about covid19ug modoanita               1      -44.509596           1
# 9                                                                                                                                                                                                                                                                                                                                           godbertumushabe janeruth aceng nurses in soroti also protesting no clarity on what the task force funds are really doing covid19ug              -1     -197.909449          -1
# 10                                                                                                                                                                                                                           janeruth aceng dianaatwine minofhealthug thank u for the great work done on handling covid19ug am inquiring have the deducted foreign covid cases from the total number been sent back to their countries or they are still in uganda ? thank you               1     -299.340238          -1
# 11                                                                                                                                                                                                                     nbsfrontline those of you waiting for govuganda to defend you infant of your landlord you might be in trouble the government may be seriously fronting a proactive strategy kindly engage your landlord hehe nbsupdates covid19ug staysafeug stopstigma              -1     -593.183119          -1
# 12                                                                                                                                                                                                                                                                                                                                                                                        do you still have plans for 2020 oba you are trying to survive to see 2021 covid19ug              -1     -143.880162          -1
# 13                                                                                                                                                                                                                                                                         simonkaggwanjal nbstv the way i see it gov t is presenting post covid19ug measures in a private sector led manner so lets brace ourselves for selfcare as they borrow more cash to eat nbsfrontline              -1     -427.241308          -1
# 14                                                                                                                                                                                                                                                                                 thank you ofwonoopondo for putting good points and defeating those all opposition leaders they should give a credit to this government of uganda on fighting against covid19ug nbsfrontline               1     -267.161678          -1
# 15                                                                                                                                                                                                                                                                                                                                     uganda just reported 5 new community covid19 cases i now smell kagutamuseveni making changes lets brace ourselves covid19ug coronavirus              -1     -238.411887          -1
# 16                                                                                                                                                                                                                                                                 covid19ug this is not good we had for some time forgotten about these community cases we continue to place our front liners in the hands of god and we pray for more blessings during this fight lockdownug              -1     -368.074092          -1
# 17                                                                                                                                                                                                                                                                                                                                                                                            janeruth aceng why is ntvuganda giving fake news 155 where are the 5 ? covid19ug              -1      -74.398447           1
# 18                                                                                                                                                                                                                                                                                                                                                                                       ntvuganda sick en tired of these covid19ug positive cases in addition to the lockdown              -1      -81.915713           1
# 19                                                                                                                                                                                                                                   covid19ug uganda loses 3bn in tourism remittances as experts see recovery in 2021 chimpreportsnews ugandanews uganda featured coronavirus businessnews tourismboardug mtwauganda govuganda mofpedu staysafeug tonsemberera masks4all news              -1     -264.573094          -1
# 20                                                                                                                                                                                                                covid19ug in order for our economy to come out of this covid 19 situation strong and resilient we shall invest 1 trillion in uganda development bank udb to support manufacturing companies and our smes to access cheap credit and create jobs for ugandans               1     -460.778668          -1
# 21                                                                                                                                                                                          on the 21st of march 2020 uganda registered its first case of coronavirus it was the darkest day of my life for my country to become a victim of the pandemic l pray each day having been in a lent period l will surely dedicate my prayers for my nation covid19ug washyourhands              -1     -535.172208          -1
# 22                                                                                                                                                                                      genoeric1 mu uganda tulinamu ebyaana n abaana the whole covid19ug and in particular food distribution was politicised you can t distribute any relief items to the public if you re opposition fdcofficial1 people power ug dpsecretariat1 but you can do anything if you re nrmonline              -1     -535.778855          -1
# 23                                                                                                                                                                                                   i like the nbsfrontline trigger the choice of who starts to give us the govt plan in oo which i haven t heard let us wait to partake what simonkaggwanjal has in store for us what is the real plan for post covid19ug ? by the way easing the opening up is not a plan !              -1     -653.684754          -1
# 24                                                                                                                                                                                                                                                                                                                                                                 the government can t stop you if you re really determined to get infected norbertmao covid19ug nbsfrontline              -1     -197.848670          -1
# 25                                                                                                                                                                                                    ntihcupdates young people have been greatly affected by the covid19ug pandemic which has further increased the unmet need for young people s srhr access to srhr services information has reduced during this time stay tuned for our feature story coming soon on nbstv              -1     -474.148541          -1
# 26                                                                                                                                                                                                                                                                                                  mayor lukwago stresses that museveni running the covid19ug fight through his own means instead of using existent agencies is the direct translation of ejoogo nbsfrontline              -1     -316.458100          -1
# 27                                                                                                                                                                                                                                                                                       covid19ug peter niwagaba a prominent businessman in kabale has donated a cow and 75kgs of rice to the drivers of the kabale covid19 taskforce for the good work exhibited kabalelocal               1     -287.964394          -1
# 28                                                                                                                                                                                                                                                                                                                                     pastor senyonga labels fellow men of god prophet elvis and yiga false prophets for giving false prophecies about covid19ug tonsemberera              -1     -291.111467          -1
# 29                                                                                                                                                                                                                           how do you rate the food aid of the 90s to that of 2020 ? nga we ate well mujoogabasajjamwe foodaid1986vs2020 covid19ug ntvuganda tbukumunhe nbstv nbsfrontline dailymonitor newvisionwire bbcafrica ntvonthespot samaemme dancunkabiito ngonians               1     -250.077646          -1
# 30                                                                                                                                                                                                                                                                                                                                                                                                     this is before sorting banange the beans are clean covid19ug staysafeug               1     -120.827964          -1
# 31                                                                                                                                                                                                                                                                                         observerug the healthcare team has been so phenomenal during the covid19ug so everything that has to been done must be considered before final conculsion mentalhealthawarenessweek               1     -256.962893          -1
# 32                                                                                                                                                                                                                                                                                                            a photo that has so many messages 1 how beautifully uganda is blessed 2 village/rural home deliveries during covid19ug 3 i bought one from him smile on his face               1     -252.173483          -1
# 33                                                                                                                                                                                                                                                                                                                                                                                            the education gap in uganda and covid19ug effect read my article about this here              -1     -148.260316          -1
# 34                                                                                                                                                                                                                                                                                                                                                           what helped when the floating island came in was the wonderful equipment we bought from japan m7address covid19ug               1     -226.459302          -1
# 35                                                                                                                                                                                                 medical professionals will facilitate webinars which will be broadcast live on ubctvuganda the aim of the partnership is to allow citizens to interact with experts and get a better context of the pandemic and govuganda efforts to protect them against covid19ug tybisa               1     -481.837018          -1
# 36                                                                                                                                                                                                                                                                                                                                                                 news we are coming for you ! mp acidri warns district leaders over covid 19 funds covid19ug westnile uganda              -1     -156.922410          -1
# 37                                                                                                                                                                                               these efforts of prevention have given us good results we have been testing people every day starting on the 21st of march up to now we have tested a big number of people the positive ones are only 79 the negative ones are 12 389 m7address covid19ug staysafeug stayhome               1     -440.448729          -1
# 38                                                                                                                                                                                                                                                                                                                                                                          ntvuganda absolutely yes and it should announce a more stimulus package as well for post covid19ug               1     -161.236382          -1
# 39                                                                                                                                                                                                 media please don t give the president a free pass on his covid19ug m7address don t simply repeat what he says provide context unmask his claims what doesn t make sense ? where are the gaps ? if he sounds incoherent or gives a confusing long winded speech call him out              -1     -629.177215          -1
# 40                                                                                                                                                                                                president museveni has pardoned 833 prisoners as part of the efforts to decongest the prisons to combat the spread of covid19ug although 833 is a small number we thank those who have been involved in this process nickopiyo and your team chapterfourug laspnetuganda etc               1     -410.576815          -1
# 41                                                                                                                                                                                                                                                                                                        great works done today loaded out a project cargo for china civil engineering and construction co thanks team for the good job not forgetting to stay safe covid19ug               1     -310.573159          -1
# 42                                                                                                                                                                                                                                                                                                                   six ways you can beat the socialdistancing blues and stay positive and connected during this period powered by mastercard covid19ug tonsemberera staysafe               1     -174.787029          -1
# 43                                                                                                                                                                                                                                                                    covid19ug has affected a lot the work of kcca since the busy center no longer collects revenue from the traders who used to make the city busy kccaug babatvuganda andrewkitaka amulaalbert sammwesigwa8              -1     -441.619173          -1
# 44                                                                                                                                      minofhealthug janeruth aceng dianaatwine kagutamuseveni jumuiya nitauganda1 mowt uganda urauganda also minofhealthug has secured two 2 gene xpert machines of 16 modules each with a capacity of 768 tests per 24 hours 1 536 tests per day they are at mutukula border point of entry janeruth aceng dianaatwine covid19ug staysafeug               1     -395.282084          -1
# 45                                                                                                                                                                                                                                                                                                          unicef has funded 14 community drives running for 3 weeks covering 11 sub counties and town councils in the western region investinugchildren staysafeug covid19ug               1     -254.284278          -1
# 46                                                                                                                                                                                                                                                                                                                                            the messages were designed by minofhealthug with support from unicefuganda and whouganda investinugchildren staysafeug covid19ug               1     -175.808635          -1
# 47                                                                                                                                                                                                                              we have donated hand sanitizers surgical face masks and pcr testing kits worth 155m ugx to the covid 19 response team at minofhealthug together we will fight this pandemic out of uganda janeruth aceng received our aid covid19ug staysafeug               1     -296.026480          -1
# 48                                                                                                                                                                                                                                                                                                                                         minofhealthug dianaatwine uvriug kccaug tegegny whouganda mauricemugisha great one ! looking forward to it ! covid19ug healthforall               1     -149.066069          -1
# 49                                                                                                                                                                                                                                                                                                                                      every little bit helps jkkarungi lizmutesi rukhshana nbstv ntvuganda rudende patriqkanyomozi luckymbabazi kanyindo kasabiiti covid19ug               1     -196.380889          -1
# 50                                                                                                                                                                                                                                                                                                                                                                                                                                                       i like this covid19ug               1      -19.067924           1
# 51                                                                                                                                                                                                                   regarding the concern of religious leaders who have been affected by covid19ug and nolonger receive offertory and other gifts the prime minister says that he has taken note of the concern raised by members and govt will definitely intervene pwatchug              -1     -580.556324          -1
# 52                                                                                                                                                                                                         for the shops and hotels let them start on the 26th of may apart from social distancing the big measure is using masks those who can get masks on their own we don t mind provided they are the right quality president museveni monitorupdates m7address covid19ug               1     -367.253441          -1
# 53                                                                                                                                                                                                                                                                                                                                           if not because my chemistry book was stolen at my high school time what is corona virus vaccines that i can t produce ? covid19ug              -1     -235.888974          -1
# 54                                                                                                                                                                                                 thank you sarahbireete the music one listens to during covid19ug time will give life and life in abundance how strategic to laugh one s problems away a laughing world would build strong immunity required to fight the pandemic annekansime janeruth aceng drpaulkasenene               1     -548.637368          -1
# 55                                                                                                                                                                                                                                                                                                          one individual in kenya sealed his wife s genitals allegedly out of jealousy a gross case of domesticabuse uganda fida uganda fidakenya chat2bo covid 19 covid19ug              -1     -260.620710          -1
# 56                                                                                                                                                                                                                             muslim journalists have received eid packages from joseph wajjala ceo one million dollar party the packages have been handed over by bbosa gonzaga wajjala thanked journalists for creating awareness about covid19ug shamimsaad2 newvisionxtra               1     -380.473602          -1
# 57                                                                                                                                                                                                     i wasn t there but i ve heard that the speaker of parliament rt hon rebeccakadagaug commended mtn uganda for the generosity they have always extended towards busoga kingdom over the years that was during the handover of ramadanwithmtn food alms in jinja covid19ug               1     -495.836635          -1
# 58                                                                                                                                                                                               with the ongoing phased reopening of the economy it s still not clear how social distancing will be effected maintained especially in the informal sector how safe are the players in this setting ? minofhealthug ameliaakyamb janeruth aceng dianaatwine mglsd ug covid19ug              -1     -437.415685          -1
# 59                                                                                                                                                                                                                                                                                                                                                                                                                                       do not miss the covid19ug facesofcare              -1      -26.303681           1
# 60                                                                                                                                                                                                                                                                                                                                                                                despite covid19ug crisis the imports continued and essential commodities have been available               1     -140.091059          -1
# 61                                                                                                                                                                                                                                                            today is current affairs talkshow night on s two foremost television stations time for regurgitation of general knowledge political head butting and clumsy showmanship coronavirus covid19ug hydroxychloriquine              -1     -207.810468          -1
# 62                                                                                                                                                                                                                                                                                                       hon peace mutuuzo says over 300 cultural events were cancelled impacting over 700 artists and their fans the economic social and emotional cost is enormous covid19ug              -1     -394.568396          -1
# 63  tonyglencross golfunion kampalapost ntvuganda 933kfm the eastafrican monitor sport mikeinuganda johnsonomolo jkmuhwezi dailymonitor mnamanya anneabeja joel khamadi kiryowakk educ sportsug and because most captains of industry will be playing there will be a quicker move to post covid19ug economic recovery right ? due to more discussions about it happening on those greens rggoobi wekesa amos that isn t ddoodo i guess ruhakanar had that in mind ! conradjvn               1     -592.705582          -1
# 64                                                                                                                                                                                                                                                                                                                                                                        also the inland port of kenya naivasha could be made available for quick clearing of goods covid19ug               1     -155.949161          -1
# 65                                                                                                                                                                                                                                                                            pastor jackson ssenyonga just made hundreds of people line up for food relief this breaks every single rule in the social distancing book cc minofhealthug govuganda policeug covid19ug courtesy              -1     -327.139585          -1
# 66                                                                                                                                                                                                           covid19ug whatsapp chat both for accurate trustworthy and up to date information this is free to use service that allows ugandans to get answers to the most common questions about covid19 from minofhealthug just save contact send any word like hi gcicuganda               1     -417.501222          -1
# 67                                                                                                                                                                                           the day more than 317 members of parliament were given ugx40 000 000 each as a token for recognizing pres museveni s fight against covid19ug is the day i lost my generosity of contributing to anything covid task force related we re a banana republic full of educated idiots              -1     -594.683541          -1
# 68                                                                                                                                                                                                                                                                                                     timely accurate information plays a critical role in protecting the health and wellbeing of all including the most vulnerable ! investinugchildren staysafeug covid19ug               1     -302.195215          -1
# 69                                                                                                                                                                                                hello honaniteevelyn it s really interseting that a 34 year old government thinks it necessary to dictate the colour of covid19ug face masks in this democratic country what i m failing to understand is the issue with black face masks ? what was the logic behind that ?              -1     -501.280457          -1
# 70                                                                                                                                                                                                                                                                                                                                    julianaakoryo unesco in love with the panelists it s such an in depth dialogue as we celebrate this culture day sharecultureug covid19ug               1     -214.645283          -1

# %% [markdown]
# ### Notice: My cluster analysis failed. My prediction result is NOT reliable, so does my accuracy test :(
