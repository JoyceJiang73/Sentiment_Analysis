# %% [markdown]
# # Unsupervisded Sentiment Analysis by word2vec + K-means clustering (1)

# %% [markdown]
# #### By Joyce Jiang | Code by Joyce

# %% [markdown]
# ### There are three steps of this unsupervised NPL analysis:
# (1) word2vec model training
#
# (2) K-means clustering to group words into positive and negative clusters
#
# (3) Perform unsupervised NLP and predict sentiments of data sample

# %% [markdown]
# ### Citation & Source of my code
# Declare: Though I have prior knowledge of conducting text categorization through word2vec and K-means, my script (from 1 to 3) is almost fully adapted from rafaljanwojciki's tutorial on GitHub, under his repo Unsupervised-Sentiment-Analysis, you can check it out at https://github.com/rafaljanwojcik/Unsupervised-Sentiment-Analysis.
#
# Thanks rafaljanwojciki for explaining in a digestible way for me to understand fully how to use word2vec and k-means for a supervised NLP. This script is published for study and research exploration purpose only, and it would not be used for any commercial purpose.

# %%
import pandas as pd
import numpy as np
import re
from re import sub
import multiprocessing
from unidecode import unidecode

from gensim.models.phrases import Phrases, Phraser
from gensim.models import Word2Vec
from gensim.test.utils import get_tmpfile
from gensim.models import KeyedVectors


from time import time 
from collections import defaultdict

import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

# %% [markdown]
# ### Import training dataset (Uganda COVID19 related content on Twitter)

# %%
file1 = pd.read_excel("Labeled/#covid19ug - Twitter Search ~ Twitter.xlsx")
file2 = pd.read_excel("Labeled/#keepingmy10k - Twitter Search ~ Twitter.xlsx")
file3 = pd.read_excel("Labeled/#MujoogabasajjaMwe until~2020-05-19 since~2020-05-01 - Twitter Search ~ Twitter.xlsx")
file4 = pd.read_excel("Labeled/(1) #COVID19UGRecovery - Twitter 搜尋 ~ Twitter.xlsx")
file5 = pd.read_excel("Labeled/(1) #PSFUEcon2020 - Twitter Search ~ Twitter.xlsx")
file6 = pd.read_excel("Labeled/(3) LDUs - Twitter Search ~ Twitter.xlsx")
file7 = pd.read_excel("Labeled/~Ministry Health Uganda~ OR ~Min Health Uganda~ OR ~MoH Uganda~ OR ~MoH UG~ OR ~Min Health UG~ OR ~Ministry Health UG~) - Twitter Search ~ Twitter.xlsx")
file8 = pd.read_excel("Labeled/covid task force uganda until~2020-05-19 since~2020-03-01 - Twitter Search ~ Twitter.xlsx")
file9 = pd.read_excel("Labeled/M7 - Twitter Search ~ Twitter.xlsx")
file10 = pd.read_excel("Labeled/Museveni - Twitter Search ~ Twitter.xlsx")
file11 = pd.read_excel("Labeled/Mzee - Twitter Search ~ Twitter.xlsx")
file12 = pd.read_excel("Labeled/Tweet_Museveni_Sentiment_Labeled_D1.xlsx")
file13 = pd.read_excel("Labeled/(1) #M7Address - Twitter ~ Twitter.xlsx")

# %%
file=pd.concat([file1['Tweet'], file2['Tweet'],file3['Tweet'], file4['Tweet'],file5['Tweet'], file6['Tweet'],file7['Tweet'], file8['Tweet']
              ,file9['Tweet'], file10['Tweet'],file11['Tweet'], file12['Tweet'],file13['Tweet']])
file=file.to_frame()

# %%
#drop duplicates 

file_cleaned = file.drop_duplicates(subset ="Tweet").reset_index(drop=True)
file_cleaned
# Out:
#                                                    Tweet
# 0      His excellency president #Uganda @KagutaMuseve...
# 1      @Katabasasa @nbstv #NBSFrontline #NBSUpdates\n...
# 2      Mr. ERIAS Lukwago should know that SOPs are in...
# 3      Energy Minister @DrKitutu hands over the Ugx.2...
# 4      15 new COVID-19 cases have been confirmed by t...
# ...                                                  ...
# 45807  The people of Najera shouldn't be given bail t...
# 45808  Is the mask thing  an example of what we gon s...
# 45809  M7 should do release us banange. Naye Tuffa #M...
# 45810  If you have a weak heart,Please stay away from...
# 45811  What if the president is having a quickie befo...
#
# [45812 rows x 1 columns]

# %% [markdown]
# #### Text cleaning

# %%
def text_to_word_list(text,remove_foreign_letters):
    ''' Pre process and convert texts to a list of words 
    method inspired by method from eliorc github repo: https://github.com/eliorc/Medium/blob/master/MaLSTM.ipynb'''
    text = remove_foreign_letters(text)
    text = str(text)
    text = text.lower()

    # Clean the text
    text = sub(r"http\S+", "", text)
    text = sub(r"[^A-Za-z0-9^,!?.\/'+]", " ", text)
    text = sub(r"\+", " plus ", text)
    text = sub(r",", " ", text)
    text = sub(r"\.", " ", text)
    text = sub(r"!", " ! ", text)
    text = sub(r"\?", " ? ", text)
    text = sub(r"'", " ", text)
    text = sub(r":", " : ", text)
    text = sub(r"\s{2,}", " ", text)

    text = text.split()

    return text

# %%
#check the cleaning result

text_to_word_list(file_cleaned['Tweet'][0],unidecode)

# %%
file_cleaned.Tweet = file_cleaned.Tweet.apply(lambda x: text_to_word_list(x, unidecode))

# %%
#filter out sentences with length smaller than 1 word

file_model = file_cleaned.copy()
file_model = file_model[file_model.Tweet.str.len()>1]

# %%
#append sentence with tokenized words

from nltk.tokenize import word_tokenize
sentences=[]

for tweet in file_model.Tweet:
#    tweet_token = word_tokenize(tweet)
    sentences.append(tweet)

# %%
#bigram function to combine words into common phrases, comment out for this test

#sent = [row for row in file_model.Tweet]
#phrases = Phrases(sent, min_count=1, progress_per=50000)
#bigram = Phraser(phrases)
#sentences = bigram[sent]
#phrases[0]

# %% [markdown]
# #### Build a word2vec model

# %%
w2v_model = Word2Vec(min_count=3,
                     window=4,
                     size=300,
                     sample=1e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=multiprocessing.cpu_count()-1)

start = time()

w2v_model.build_vocab(sentences, progress_per=50000)

print('Time to build vocab: {} mins'.format(round((time() - start) / 60, 2)))
# Out:
# INFO - 17:00:45: collecting all words and their counts
# INFO - 17:00:45: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 17:00:45: collected 81374 word types from a corpus of 868346 raw words and 45043 sentences
# INFO - 17:00:45: Loading a fresh vocabulary
# INFO - 17:00:45: effective_min_count=3 retains 20847 unique words (25% of original 81374, drops 60527)
# INFO - 17:00:45: effective_min_count=3 leaves 797256 word corpus (91% of original 868346, drops 71090)
# INFO - 17:00:45: deleting the raw counts dictionary of 81374 items
# INFO - 17:00:45: sample=1e-05 downsamples 4194 most-common words
# INFO - 17:00:45: downsampling leaves estimated 252725 word corpus (31.7% of prior 797256)
# INFO - 17:00:45: estimated required memory for 20847 words and 300 dimensions: 60456300 bytes
# INFO - 17:00:45: resetting layer weights
# Time to build vocab: 0.07 mins

# %% [markdown]
# #### Train a word2vec model (takes around 40 seconds)

# %%
start = time()

w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)

print('Time to train the model: {} mins'.format(round((time() - start) / 60, 2)))

w2v_model.init_sims(replace=True)
# Out:
# INFO - 17:01:44: training model with 3 workers on 20847 vocabulary and 300 features, using sg=0 hs=0 sample=1e-05 negative=20 window=4
# INFO - 17:01:45: EPOCH 1 - PROGRESS: at 82.56% examples, 217238 words/s, in_qsize 5, out_qsize 0
# INFO - 17:01:45: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:45: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:45: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:45: EPOCH - 1 : training on 868346 raw words (252330 effective words) took 1.1s, 227313 effective words/s
# INFO - 17:01:45: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:45: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:45: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:45: EPOCH - 2 : training on 868346 raw words (252943 effective words) took 0.7s, 346627 effective words/s
# INFO - 17:01:46: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:46: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:46: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:46: EPOCH - 3 : training on 868346 raw words (252455 effective words) took 0.7s, 351393 effective words/s
# INFO - 17:01:47: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:47: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:47: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:47: EPOCH - 4 : training on 868346 raw words (253112 effective words) took 0.7s, 351553 effective words/s
# INFO - 17:01:48: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:48: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:48: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:48: EPOCH - 5 : training on 868346 raw words (252781 effective words) took 0.7s, 345881 effective words/s
# INFO - 17:01:48: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:48: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:48: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:48: EPOCH - 6 : training on 868346 raw words (252009 effective words) took 0.8s, 322275 effective words/s
# INFO - 17:01:49: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:49: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:49: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:49: EPOCH - 7 : training on 868346 raw words (252767 effective words) took 0.8s, 315337 effective words/s
# INFO - 17:01:50: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:50: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:50: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:50: EPOCH - 8 : training on 868346 raw words (253014 effective words) took 0.8s, 332659 effective words/s
# INFO - 17:01:51: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:51: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:51: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:51: EPOCH - 9 : training on 868346 raw words (252569 effective words) took 0.7s, 336979 effective words/s
# INFO - 17:01:52: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:52: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:52: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:52: EPOCH - 10 : training on 868346 raw words (252814 effective words) took 0.8s, 316588 effective words/s
# INFO - 17:01:52: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:52: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:52: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:52: EPOCH - 11 : training on 868346 raw words (252924 effective words) took 0.7s, 343623 effective words/s
# INFO - 17:01:53: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:53: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:53: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:53: EPOCH - 12 : training on 868346 raw words (252121 effective words) took 0.8s, 335486 effective words/s
# INFO - 17:01:54: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:54: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:54: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:54: EPOCH - 13 : training on 868346 raw words (253417 effective words) took 0.8s, 318863 effective words/s
# INFO - 17:01:55: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:55: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:55: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:55: EPOCH - 14 : training on 868346 raw words (252222 effective words) took 0.8s, 307690 effective words/s
# INFO - 17:01:56: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:56: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:56: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:56: EPOCH - 15 : training on 868346 raw words (252161 effective words) took 0.9s, 295911 effective words/s
# INFO - 17:01:56: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:56: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:56: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:56: EPOCH - 16 : training on 868346 raw words (252869 effective words) took 0.8s, 321671 effective words/s
# INFO - 17:01:57: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:57: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:57: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:57: EPOCH - 17 : training on 868346 raw words (252524 effective words) took 0.8s, 324637 effective words/s
# INFO - 17:01:58: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:58: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:58: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:58: EPOCH - 18 : training on 868346 raw words (252552 effective words) took 0.8s, 319452 effective words/s
# INFO - 17:01:59: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:59: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:59: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:59: EPOCH - 19 : training on 868346 raw words (252956 effective words) took 0.8s, 313896 effective words/s
# INFO - 17:01:59: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:01:59: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:01:59: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:01:59: EPOCH - 20 : training on 868346 raw words (253388 effective words) took 0.7s, 356421 effective words/s
# INFO - 17:02:00: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:02:00: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:02:00: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:02:00: EPOCH - 21 : training on 868346 raw words (252315 effective words) took 0.7s, 354003 effective words/s
# INFO - 17:02:01: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:02:01: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:02:01: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:02:01: EPOCH - 22 : training on 868346 raw words (252433 effective words) took 0.7s, 356749 effective words/s
# INFO - 17:02:02: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:02:02: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:02:02: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:02:02: EPOCH - 23 : training on 868346 raw words (251953 effective words) took 0.7s, 363378 effective words/s
# INFO - 17:02:02: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:02:02: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:02:02: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:02:02: EPOCH - 24 : training on 868346 raw words (252596 effective words) took 0.7s, 357529 effective words/s
# INFO - 17:02:03: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:02:03: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:02:03: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:02:03: EPOCH - 25 : training on 868346 raw words (252304 effective words) took 0.7s, 350833 effective words/s
# INFO - 17:02:04: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:02:04: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:02:04: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:02:04: EPOCH - 26 : training on 868346 raw words (252573 effective words) took 0.8s, 333165 effective words/s
# INFO - 17:02:05: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:02:05: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:02:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:02:05: EPOCH - 27 : training on 868346 raw words (252794 effective words) took 0.8s, 317181 effective words/s
# INFO - 17:02:05: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:02:05: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:02:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:02:05: EPOCH - 28 : training on 868346 raw words (252531 effective words) took 0.8s, 329766 effective words/s
# INFO - 17:02:06: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:02:06: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:02:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:02:06: EPOCH - 29 : training on 868346 raw words (252594 effective words) took 0.7s, 355061 effective words/s
# INFO - 17:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 17:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 17:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 17:02:07: EPOCH - 30 : training on 868346 raw words (252572 effective words) took 0.7s, 348284 effective words/s
# INFO - 17:02:07: training on a 26050380 raw words (7578593 effective words) took 23.2s, 327047 effective words/s
# INFO - 17:02:07: precomputing L2-norms of word weight vectors
# Time to train the model: 0.39 mins

# %%
#Save w2v model for future usage 

w2v_model.save("word2vec.model")
# Out:
# INFO - 17:02:25: saving Word2Vec object under word2vec.model, separately None
# INFO - 17:02:25: not storing attribute vectors_norm
# INFO - 17:02:25: not storing attribute cum_table
# INFO - 17:02:27: saved word2vec.model

# %% [markdown]
# ## Preprocess data sample for word2vec to perform vectorization

# %%
file = pd.read_excel("Labeled/Covid19UG_NoDuplicates23_05_20_labeled.xlsx")
file
# Out:
#       Unnamed: 0  Row ID             Tweet ID         Username  \
# 0              0       1  1263678902041526016      AhmadiyyaUg
# 1              1       4  1263678714124153088      NansinguzaJ
# 2              2       7  1263677791222074880   SolomonMGrace2
# 3              3       8  1263676429994254080   Cotildakhainza
# 4              4       9  1263674084405252096  matookerepublic
# ...          ...     ...                  ...              ...
# 5056        5056   16824  1260636518072421888           OWC_ug
# 5057        5057   16826  1260636408328356096      OworiSylvia
# 5058        5058   16838  1260630805971374080         i_kagoya
# 5059        5059   16839  1260630418816225024      JenifaOchwo
# 5060        5060   16845  1260629530391313920  whispereye_news
#
#                                                   Tweet  \
# 0     His excellency president #Uganda @KagutaMuseve...
# 1     @Katabasasa @nbstv #NBSFrontline #NBSUpdates\n...
# 2     Mr. ERIAS Lukwago should know that SOPs are in...
# 3     Energy Minister @DrKitutu hands over the Ugx.2...
# 4     15 new COVID-19 cases have been confirmed by t...
# ...                                                 ...
# 5056  @OworiSylvia : We have been engaging directly ...
# 5057  Major Rubalamira: @OWC_ug has been supplied by...
# 5058  It is going to be very difficult for governmen...
# 5059  For making the #COVID19UG lockdown bearable......
# 5060  @JanetMuseveni  on learning !\n#News #ThankYou...
#
#                        Time Tweet Type     Retweeted By  Number of Retweets  \
# 0      5/21/2020 8:51:42 PM    Retweet  AhmadiyyaKings1                   4
# 1      5/21/2020 8:50:58 PM      Tweet              NaN                   0
# 2      5/21/2020 8:47:18 PM    Retweet         kugonza6                   1
# 3      5/21/2020 8:41:53 PM    Retweet          h_ssali                  18
# 4      5/21/2020 8:32:34 PM    Retweet       KKabajwisa                   1
# ...                     ...        ...              ...                 ...
# 5056  5/13/2020 11:22:22 AM    Retweet          jbogube                   2
# 5057  5/13/2020 11:21:55 AM    Retweet          jbogube                  14
# 5058  5/13/2020 10:59:40 AM    Retweet  ElliotOrizaarwa                   1
# 5059  5/13/2020 10:58:07 AM    Retweet       TheLoveDre                   1
# 5060  5/13/2020 10:54:36 AM      Tweet              NaN                   0
#
#                                               Hashtags  \
# 0                           Uganda Ahmadiyya COVID19UG
# 1           NBSFrontline NBSUpdates COVID19UG Covid_19
# 2                                                  NaN
# 3                                            COVID19UG
# 4                                                  NaN
# ...                                                ...
# 5056                                               NaN
# 5057                                               NaN
# 5058                                               NaN
# 5059                        COVID19UG ThankYouUgandans
# 5060  News ThankYouUgandans Uganda Education COVID19UG
#
#                                                Mentions                  Name  \
# 0     KagutaMuseveni HumanityFirstUK UgHumanityfirst...       AhmadiyyaUganda
# 1                                      Katabasasa nbstv      Nansinguza Jacob
# 2              JudiciaryUG peter_katwesige OfwonoOpondo    Male Solomon Grace
# 3                                DrKitutu Parliament_Ug          Psycho
# 4                                                   NaN      Matooke Republic
# ...                                                 ...                   ...
# 5056                              OworiSylvia OPMUganda    Wealth Creation Ug
# 5057  OWC_ug GovUganda OPMUganda MAAIF_Uganda Parlia...  Sylvia Damalie Owori
# 5058                           KagutaMuseveni RuhakanaR          Irene Kagoya
# 5059                                                NaN          Jenifa Ochwo
# 5060                                      JanetMuseveni           Whisper Eye
#
#              Location                      Web  \
# 0                 NaN                      NaN
# 1              Uganda  https://t.co/8zcFVolmZH
# 2     Kampala, Uganda  https://t.co/CUY7tvkw87
# 3     Kampala, Uganda                      NaN
# 4     Kampala, Uganda  https://t.co/4au2z8o6u8
# ...               ...                      ...
# 5056           Uganda  https://t.co/QacjAzznSK
# 5057              NaN                      NaN
# 5058   Kampala Uganda                      NaN
# 5059           Uganda                      NaN
# 5060  Kampala, Uganda  https://t.co/1CvaiPnMva
#
#                                                     Bio  Number of Tweets  \
# 0     Official Twitter Handle of Uganda Ahmadiyya Mu...               110
# 1     #VisualCommunication #MedicaIillustration & #E...             38917
# 2     Public Administrator, Policy Researcher and An...              8851
# 3     Student of MAKERERE University Kampala. PURSUI...              1636
# 4                                   Freshly Peeled Info              7186
# ...                                                 ...               ...
# 5056  Our mission is ''To improve household income t...              2328
# 5057  Exec Assistant to the CC of Operation Wealth C...                48
# 5058  A lawyer,  & Women's Rights Activist,   workin...              3826
# 5059  Thinker | Faith | Entertainment | Justice | Go...             30887
# 5060  Whisper Eye a world leading independent online...              1310
#
#       Number of Followers  Number Following  Location Coordinates  SENTIMENT
# 0                     155               438                   NaN        1.0
# 1                    3300              4103         +01.25+032.5/        NaN
# 2                    1246              5009  +00.31628+032.58219/        NaN
# 3                    1341              1206  +00.31628+032.58219/        NaN
# 4                    2516               342  +00.31628+032.58219/        NaN
# ...                   ...               ...                   ...        ...
# 5056                 3353               715         +01.25+032.5/        NaN
# 5057                   83               107                   NaN        NaN
# 5058                  792               851  +00.31628+032.58219/        NaN
# 5059                 3221               831         +01.25+032.5/        NaN
# 5060                  337                57  +00.31628+032.58219/        NaN
#
# [5061 rows x 20 columns]

# %%
file_cleaned = file.drop_duplicates(subset ="Tweet").reset_index(drop=True)
file_cleaned.Tweet = file_cleaned.Tweet.apply(lambda x: text_to_word_list(x, unidecode))
file_model = file_cleaned.copy()
file_model = file_model[file_model.Tweet.str.len()>1]

sentences=[]

for tweet in file_model.Tweet:
#    tweet_token = word_tokenize(tweet)
    sentences.append(tweet)

# %%
sentences[0]
# Out:
# ['his',
#  'excellency',
#  'president',
#  'uganda',
#  'kagutamuseveni',
#  'recognising',
#  'efforts',
#  'of',
#  'ahmadiyya',
#  'muslim',
#  'community',
#  'towards',
#  'covid19ug',
#  'so',
#  'grateful',
#  'to',
#  'our',
#  'partners',
#  'humanityfirstuk',
#  'ughumanityfirst',
#  'hfi1995',
#  '4',
#  'support',
#  'accorded',
#  'to',
#  'the',
#  'ppl',
#  'of',
#  'uganda',
#  'ntvuganda',
#  'eidmubarak',
#  'eidulfitr',
#  'nbsupdates']

# %%
file_export = file_model.copy()
file_export['old_Tweet'] = file_export.Tweet
file_export.old_Tweet = file_export.old_Tweet.str.join(' ')
file_export.Tweet = sentences
#file_export.rate = file_export.rate.astype('int8')

# %%
file_export[['Tweet','old_Tweet','SENTIMENT']]
# Out:
#                                                   Tweet  \
# 0     [his, excellency, president, uganda, kagutamus...
# 1     [katabasasa, nbstv, nbsfrontline, nbsupdates, ...
# 2     [mr, erias, lukwago, should, know, that, sops,...
# 3     [energy, minister, drkitutu, hands, over, the,...
# 4     [15, new, covid, 19, cases, have, been, confir...
# ...                                                 ...
# 5056  [oworisylvia, we, have, been, engaging, direct...
# 5057  [major, rubalamira, owc, ug, has, been, suppli...
# 5058  [it, is, going, to, be, very, difficult, for, ...
# 5059  [for, making, the, covid19ug, lockdown, bearab...
# 5060  [janetmuseveni, on, learning, !, news, thankyo...
#
#                                               old_Tweet  SENTIMENT
# 0     his excellency president uganda kagutamuseveni...        1.0
# 1     katabasasa nbstv nbsfrontline nbsupdates alrig...        NaN
# 2     mr erias lukwago should know that sops are ins...        NaN
# 3     energy minister drkitutu hands over the ugx 20...        NaN
# 4     15 new covid 19 cases have been confirmed by t...        NaN
# ...                                                 ...        ...
# 5056  oworisylvia we have been engaging directly the...        NaN
# 5057  major rubalamira owc ug has been supplied by t...        NaN
# 5058  it is going to be very difficult for governmen...        NaN
# 5059  for making the covid19ug lockdown bearable tha...        NaN
# 5060  janetmuseveni on learning ! news thankyouugand...        NaN
#
# [5032 rows x 3 columns]

# %%
file_export[['Tweet','old_Tweet','SENTIMENT']].to_csv('test_dataset.csv', index=False)
